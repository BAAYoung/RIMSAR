# %%
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.interpolate import LinearNDInterpolator
from scipy.ndimage import gaussian_filter

# %%
def shear_statistics(case):
    data = np.loadtxt('NonNewtonian/cavityNonNewtonian_'+case+'_0.csv',delimiter = ',')
    u_data = data[:,1] 
    v_data = data[:,2]
    X = data[:,4]
    Z = data[:,5]

    dx = 0.02
    xx,zz = np.meshgrid(np.arange(0,1.0+dx,dx),np.arange(0,1.0+dx,dx))
    u_interp = LinearNDInterpolator(list(zip(X,Z)), u_data)
    v_interp = LinearNDInterpolator(list(zip(X,Z)), v_data)

    u1 = u_interp(xx,zz)
    v1 = v_interp(xx,zz)

    return u1

# %%
dx = 0.02
xx,zz = np.meshgrid(np.arange(0,1.0+dx,dx),np.arange(0,1.0+dx,dx))

case0 = 'n0_5_k0_1'
u0 = shear_statistics(case0)
case1 = 'n0_5_k0_001'
u1 = shear_statistics(case1)
case2 = 'n2_k0_001'
u2 = shear_statistics(case2)
plt.contourf(xx,zz,u0)
plt.colorbar()

# %%
plt.contourf(xx,zz,u1)
plt.colorbar()

# %%
plt.contourf(xx,zz,u2) 
plt.colorbar()
