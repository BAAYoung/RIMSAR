# %% [markdown]
# This file is for plotting the RIMS data that has been processed into coarse grained fields

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.ndimage import gaussian_filter
from scipy.interpolate import LinearNDInterpolator

# %%
#data = np.loadtxt('/home/bay22/git_repositories/RIMSAR/data/03_processed/RIMS_data_vector.dat')
#data = np.loadtxt('cavityNonNewtonian_n2_k0_01_0.csv',delimiter = ',')
data = np.loadtxt('/home/bay22/git_repositories/RIMSAR/data/03_processed/coarse_grain/RCG_c0_01.dat')
plt.figure(figsize=(8,8))
u_data = data[:,3] 
v_data = -data[:,4]
rho_data = data[:,2]
Xu = data[:,0]
Zu = data[:,1]



dt = 0.01
pixel2real = 0.0001848337
xc = 467.5*pixel2real
zc = -388.6*pixel2real
R = 525*pixel2real
theta = np.arange(0,2*3.14159+dt,dt)
xcircle = xc + R*np.sin(theta)
zcircle = zc + R*np.cos(theta)
xline = np.arange(0,0.2,0.01)
m = 0.6
#c = -0.155
c= -0.15

#c = -0.17
yline = xline*m + c

plt.tricontourf(Xu,Zu,rho_data)
plt.plot(xline,yline)
